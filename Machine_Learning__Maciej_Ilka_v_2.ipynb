# %% [markdown]
# <a href="https://colab.research.google.com/github/sbs23092/introduction_to_ml_with_python/blob/master/Machine_Learning__Maciej_Ilka_v_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings #import warnings 
warnings.filterwarnings('ignore') #ignore warnings 

# %matplotlib inline 
import numpy as np #numerical operations 
import pandas as pd #data manipulation
from sklearn.decomposition import PCA #import PCA for scikit-learn
import seaborn as sns; #data visualization
import matplotlib.pyplot as plt #plotting 
sns.set() #deffault plotting style
import mglearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression #linearregression

# %%
#open library
df = pd.read_csv('PopulationByAgeSex.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66893 entries, 0 to 66892
# Data columns (total 71 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 66893 non-null  int64
#  1   LocID              66893 non-null  int64
#  2   Location           66893 non-null  object
#  3   Time               66893 non-null  int64
#  4   PopMale_0_4        66893 non-null  float64
#  5   PopFemale_0_4      66893 non-null  float64
#  6   PopTotal_0_4       66893 non-null  float64
#  7   PopMale_5_9        66893 non-null  float64
#  8   PopFemale_5_9      66893 non-null  float64
#  9   PopTotal_5_9       66893 non-null  float64
#  10  PopMale_10_14      66893 non-null  float64
#  11  PopFemale_10_14    66893 non-null  float64
#  12  PopTotal_10_14     66893 non-null  float64
#  13  PopMale_15_19      66893 non-null  float64
#  14  PopFemale_15_19    66893 non-null  float64
# ...

# %%
df.head()
# Out:
#    Id  LocID     Location  Time  PopMale_0_4  PopFemale_0_4  PopTotal_0_4  \
# 0   1      4  Afghanistan  1950      630.044        661.578      1291.622
# 1   2      4  Afghanistan  1951      641.199        673.293      1314.492
# 2   3      4  Afghanistan  1952      650.825        669.274      1320.099
# 3   4      4  Afghanistan  1953      659.896        663.606      1323.502
# 4   5      4  Afghanistan  1954      670.694        663.295      1333.989
#
#    PopMale_5_9  PopFemale_5_9  PopTotal_5_9  ...  PopMale_95_99  \
# 0      516.206        487.335      1003.541  ...          0.004
# 1      525.302        502.402      1027.704  ...          0.007
# 2      533.097        521.672      1054.769  ...          0.012
# 3      538.351        541.216      1079.567  ...          0.015
# 4      540.820        557.196      1098.016  ...          0.014
#
#    PopFemale_95_99  PopTotal_95_99  PopMale_100Plus  PopFemale_100Plus  \
# ...

# %%
df.shape
# Out:
# (66893, 71)

# %%
df.isnull().sum()
# Out:
# Id                   0
# LocID                0
# Location             0
# Time                 0
# PopMale_0_4          0
#                     ..
# PopTotal_100Plus     0
# PopMale              0
# PopFemale            0
# PopTotal             0
# YearDataCompleted    0
# Length: 71, dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# Id                   0.0
# LocID                0.0
# Location             0.0
# Time                 0.0
# PopMale_0_4          0.0
#                     ...
# PopTotal_100Plus     0.0
# PopMale              0.0
# PopFemale            0.0
# PopTotal             0.0
# YearDataCompleted    0.0
# Length: 71, dtype: float64

# %% [markdown]
# # Drop columns

# %%
df = df.drop(columns=["PopMale_0_4","PopFemale_0_4","PopMale_5_9", "PopFemale_5_9", "PopMale_10_14","PopFemale_10_14","PopMale_15_19","PopFemale_15_19","PopMale_20_24","PopFemale_20_24","PopMale_25_29","PopFemale_25_29","PopMale_30_34","PopFemale_30_34","PopMale_35_39","PopFemale_35_39","PopMale_40_44","PopFemale_40_44","PopMale_45_49","PopFemale_45_49","PopMale_50_54","PopFemale_50_54","PopMale_55_59","PopFemale_55_59","PopMale_60_64","PopFemale_60_64","PopMale_65_69","PopFemale_65_69","PopMale_70_74","PopFemale_70_74","PopMale_75_79","PopFemale_75_79","PopMale_80_84","PopFemale_80_84","PopMale_85_89","PopFemale_85_89","PopMale_90_94","PopFemale_90_94","PopMale_95_99","PopFemale_95_99","PopMale_100Plus","PopFemale_100Plus","YearDataCompleted"])
df.head()
# Out:
#    Id  LocID     Location  Time  PopTotal_0_4  PopTotal_5_9  PopTotal_10_14  \
# 0   1      4  Afghanistan  1950      1291.622      1003.541         884.704
# 1   2      4  Afghanistan  1951      1314.492      1027.704         893.229
# 2   3      4  Afghanistan  1952      1320.099      1054.769         906.756
# 3   4      4  Afghanistan  1953      1323.502      1079.567         924.266
# 4   5      4  Afghanistan  1954      1333.989      1098.016         944.377
#
#    PopTotal_15_19  PopTotal_20_24  PopTotal_25_29  ...  PopTotal_70_74  \
# 0         783.732         692.501         593.610  ...          67.200
# 1         790.341         698.280         600.495  ...          68.531
# 2         801.420         705.872         610.058  ...          69.609
# 3         814.914         714.436         620.763  ...          70.394
# 4         829.684         724.190         631.571  ...          70.870
#
#    PopTotal_75_79  PopTotal_80_84  PopTotal_85_89  PopTotal_90_94  \
# ...

# %%
europe_df = df.loc[df['LocID'] == 917]

# %%
europe_df.head(20)
# Out:
#           Id  LocID Location  Time  PopTotal_0_4  PopTotal_5_9  \
# 24463  24464    917   Europe  1950     51684.264     41977.805
# 24465  24466    917   Europe  1951     54788.322     41450.179
# 24467  24468    917   Europe  1952     55479.494     42511.680
# 24469  24470    917   Europe  1953     55454.645     44986.231
# 24471  24472    917   Europe  1954     55361.766     48115.614
# 24473  24474    917   Europe  1955     55579.608     50677.194
# 24475  24476    917   Europe  1956     55120.080     52705.800
# 24477  24478    917   Europe  1957     55413.420     54050.806
# 24479  24480    917   Europe  1958     56112.321     54675.383
# 24481  24482    917   Europe  1959     56795.416     54868.802
# 24483  24484    917   Europe  1960     57151.744     55127.098
# 24485  24486    917   Europe  1961     57456.622     55566.551
# 24487  24488    917   Europe  1962     57477.381     56009.522
# 24489  24490    917   Europe  1963     57208.182     56451.850
# ...

# %% [markdown]
# # Linear Regression

# %%
# split dataset in features and target variable
feature_cols = ['PopTotal']
X = europe_df[feature_cols]               # Features of the dataset
y = europe_df.Time                      # Target variable of the dataset

# Display the X and y arrays
print(X, y)
# Out:
#          PopTotal
# 24463  549328.859
# 24465  554324.506
# 24467  559694.362
# 24469  565281.964
# 24471  570969.740
# ...           ...
# 24755  633059.951
# 24757  632199.281
# 24759  631333.521
# 24761  630456.833
# 24763  629562.562
#
# [151 rows x 1 columns] 24463    1950
# 24465    1951
# 24467    1952
# 24469    1953
# 24471    1954
#          ...
# 24755    2096
# 24757    2097
# 24759    2098
# 24761    2099
# 24763    2100
# Name: Time, Length: 151, dtype: int64

# %%
# Store and load the dataset 
X = europe_df[feature_cols]               # Features of the dataset
y = europe_df.Time   
X.shape, y.shape
# Out:
# ((151, 1), (151,))

# %%
#X and y are the array variables that store the independent and dependent variables
X, y = mglearn.datasets.make_wave(n_samples = 60)

# Call the train_test_split method to split the data and the default splitting is 75% for training and 25% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 40)

# Train the LinearRegression mode by using a method fit() function/ method
lr = LinearRegression().fit(X_train, y_train)

# %%
# Display the coefficient and intercept values
print("lr.coef_: {}".format(lr.coef_))
print("lr.intercept_: {}".format(lr.intercept_))
# Out:
# lr.coef_: [0.41903332]
# lr.intercept_: -0.09450848331906847

# %%
# Display the score values by calling lr
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.65
# Test set score: 0.74

# %%
# Split the dataset by using train_test_splitting to 25% and 75% for training
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# Use LinearRegression() model to train the data
lr = LinearRegression().fit(X_train, y_train)

# %%
# Display the score using format function
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.66
# Test set score: 0.69

# %%
asia_df = df.loc[df['LocID'] == 935]

# %%
africa_df = df.loc[df['LocID'] == 903]

# %%
centralamerica_df = df.loc[df['LocID'] == 916]

# %%
southamerica_df = df.loc[df['LocID'] == 931]

# %%
oceania_df = df.loc[df['LocID'] == 909]

# %%
northeramerica_df = df.loc[df['LocID'] == 905]

# %%
europe_df.shape
# Out:
# (151, 28)

# %%
dfs_dict = {'europe_df': df.loc[df['LocID'] == 917],
            'asia_df': df.loc[df['LocID'] == 935],
            'africa_df': df.loc[df['LocID'] == 903],
            'centralamerica_df': df.loc[df['LocID'] == 916],
            'southamerica_df': df.loc[df['LocID'] == 931],
            'oceania_df': df.loc[df['LocID'] == 909],
            'northeramerica_df': df.loc[df['LocID'] == 905]}

# %%
dfs_dict.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gn/s4m2wb952mn2hvvtn0qvwxgr0000gn/T/ipykernel_12473/2593841697.py in <module>
# ----> 1 dfs_dict.shape
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
df = pd.get_dummies(df)
df.shape

# %%
df.columns.to_list()

# %%
df = df.drop(columns=['Location_Afghanistan',
 'Location_African Group',
 'Location_African Union',
 'Location_African Union: Central Africa',
 'Location_African Union: Eastern Africa',
 'Location_African Union: Northern Africa',
 'Location_African Union: Southern Africa',
 'Location_African Union: Western Africa',
 'Location_African; Caribbean and Pacific (ACP) Group of States',
 'Location_Albania',
 'Location_Algeria',
 'Location_Andean Community',
 'Location_Angola',
 'Location_Antigua and Barbuda',
 'Location_Argentina',
 'Location_Armenia',
 'Location_Aruba',
 'Location_Asia-Pacific Economic Cooperation (APEC)',
 'Location_Asia-Pacific Group',
 'Location_Association of Southeast Asian Nations (ASEAN)',
 'Location_Australia',
 'Location_Australia/New Zealand',
 'Location_Austria',
 'Location_Azerbaijan',
 'Location_BRIC',
 'Location_BRICS',
 'Location_Bahamas',
 'Location_Bahrain',
 'Location_Bangladesh',
 'Location_Barbados',
 'Location_Belarus',
 'Location_Belgium',
 'Location_Belize',
 'Location_Belt-Road Initiative (BRI)',
 'Location_Belt-Road Initiative: Africa',
 'Location_Belt-Road Initiative: Asia',
 'Location_Belt-Road Initiative: Europe',
 'Location_Belt-Road Initiative: Latin America and the Caribbean',
 'Location_Belt-Road Initiative: Pacific',
 'Location_Benin',
 'Location_Bhutan',
 'Location_Black Sea Economic Cooperation (BSEC)',
 'Location_Bolivarian Alliance for the Americas (ALBA)',
 'Location_Bolivia (Plurinational State of)',
 'Location_Bosnia and Herzegovina',
 'Location_Botswana',
 'Location_Brazil',
 'Location_Brunei Darussalam',
 'Location_Bulgaria',
 'Location_Burkina Faso',
 'Location_Burundi',
 'Location_Cabo Verde',
 'Location_Cambodia',
 'Location_Cameroon',
 'Location_Canada',
 'Location_Caribbean',
 'Location_Caribbean Community and Common Market (CARICOM)',
 'Location_Central African Republic',
 'Location_Central Asia',
 'Location_Central European Free Trade Agreement (CEFTA)',
 'Location_Central and Southern Asia',
 'Location_Chad',
 'Location_Channel Islands',
 'Location_Chile',
 'Location_China',
 'Location_China (and dependencies)',
 'Location_China; Hong Kong SAR',
 'Location_China; Macao SAR',
 'Location_China; Taiwan Province of China',
 'Location_Colombia',
 'Location_Commonwealth of Independent States (CIS)',
 'Location_Commonwealth of Nations',
 'Location_Commonwealth: Africa',
 'Location_Commonwealth: Asia',
 'Location_Commonwealth: Caribbean and Americas',
 'Location_Commonwealth: Europe',
 'Location_Commonwealth: Pacific',
 'Location_Comoros',
 'Location_Congo',
 'Location_Costa Rica',
 'Location_Countries with Access to the Sea',
 'Location_Countries with Access to the Sea: Africa',
 'Location_Countries with Access to the Sea: Asia',
 'Location_Countries with Access to the Sea: Europe',
 'Location_Countries with Access to the Sea: Latin America and the Caribbean',
 'Location_Countries with Access to the Sea: Northern America',
 'Location_Countries with Access to the Sea: Oceania',
 'Location_Croatia',
 'Location_Cuba',
 'Location_Curaçao',
 'Location_Cyprus',
 'Location_Czechia',
 "Location_Côte d'Ivoire",
 "Location_Dem. People's Republic of Korea",
 'Location_Democratic Republic of the Congo',
 'Location_Denmark',
 'Location_Denmark (and dependencies)',
 'Location_Djibouti',
 'Location_Dominican Republic',
 'Location_ECE: North America-2',
 'Location_ECE: UNECE-52',
 'Location_ECLAC: Latin America',
 'Location_ECLAC: The Caribbean',
 'Location_ESCAP region: East and North-East Asia',
 'Location_ESCAP region: North and Central Asia',
 'Location_ESCAP region: Pacific',
 'Location_ESCAP region: South and South-West Asia',
 'Location_ESCAP region: South-East Asia',
 'Location_ESCAP: ADB Developing member countries (DMCs)',
 'Location_ESCAP: ADB Group A (Concessional assistance\xa0only)',
 'Location_ESCAP: ADB Group B\xa0(OCR blend)',
 'Location_ESCAP: ADB Group C (Regular OCR only)',
 'Location_ESCAP: ASEAN',
 'Location_ESCAP: Central Asia',
 'Location_ESCAP: ECO',
 'Location_ESCAP: HDI groups',
 'Location_ESCAP: Landlocked countries (LLDCs)',
 'Location_ESCAP: Least Developed Countries (LDCs)',
 'Location_ESCAP: Pacific island dev. econ.',
 'Location_ESCAP: SAARC',
 'Location_ESCAP: WB High income econ.',
 'Location_ESCAP: WB Low income econ.',
 'Location_ESCAP: WB Lower middle income econ.',
 'Location_ESCAP: WB Upper middle income econ.',
 'Location_ESCAP: WB income groups',
 'Location_ESCAP: high HDI',
 'Location_ESCAP: high income',
 'Location_ESCAP: income groups',
 'Location_ESCAP: low HDI',
 'Location_ESCAP: low income',
 'Location_ESCAP: lower middle HDI',
 'Location_ESCAP: lower middle income',
 'Location_ESCAP: other Asia-Pacific countries/areas',
 'Location_ESCAP: upper middle HDI',
 'Location_ESCAP: upper middle income',
 'Location_ESCWA: Arab countries',
 'Location_ESCWA: Arab least developed countries',
 'Location_ESCWA: Gulf Cooperation Council countries',
 'Location_ESCWA: Maghreb countries',
 'Location_ESCWA: Mashreq countries',
 'Location_ESCWA: member countries',
 'Location_East African Community (EAC)',
 'Location_Eastern Africa',
 'Location_Eastern Asia',
 'Location_Eastern Europe',
 'Location_Eastern European Group',
 'Location_Eastern and South-Eastern Asia',
 'Location_Economic Community of Central African States (ECCAS)',
 'Location_Economic Community of West African States (ECOWAS)',
 'Location_Economic Cooperation Organization (ECO)',
 'Location_Ecuador',
 'Location_Egypt',
 'Location_El Salvador',
 'Location_Equatorial Guinea',
 'Location_Eritrea',
 'Location_Estonia',
 'Location_Eswatini',
 'Location_Ethiopia',
 'Location_Eurasian Economic Community (Eurasec)',
 'Location_Europe (48)',
 'Location_Europe and Northern America',
 'Location_European Community (EC: 12)',
 'Location_European Free Trade Agreement (EFTA)',
 'Location_European Union (EU: 15)',
 'Location_European Union (EU: 28)',
 'Location_Fiji',
 'Location_Finland',
 'Location_France',
 'Location_France (and dependencies)',
 'Location_French Guiana',
 'Location_French Polynesia',
 'Location_Gabon',
 'Location_Gambia',
 'Location_Georgia',
 'Location_Germany',
 'Location_Ghana',
 'Location_Greater Arab Free Trade Area (GAFTA)',
 'Location_Greece',
 'Location_Grenada',
 'Location_Group of 77 (G77)',
 'Location_Group of Eight (G8)',
 'Location_Group of Seven (G7)',
 'Location_Group of Twenty (G20) - member states',
 'Location_Guadeloupe',
 'Location_Guam',
 'Location_Guatemala',
 'Location_Guinea',
 'Location_Guinea-Bissau',
 'Location_Gulf Cooperation Council (GCC)',
 'Location_Guyana',
 'Location_Haiti',
 'Location_High-income countries',
 'Location_Honduras',
 'Location_Hungary',
 'Location_Iceland',
 'Location_India',
 'Location_Indonesia',
 'Location_Iran (Islamic Republic of)',
 'Location_Iraq',
 'Location_Ireland',
 'Location_Israel',
 'Location_Italy',
 'Location_Jamaica',
 'Location_Japan',
 'Location_Jordan',
 'Location_Kazakhstan',
 'Location_Kenya',
 'Location_Kiribati',
 'Location_Kuwait',
 'Location_Kyrgyzstan',
 'Location_LLDC: Africa',
 'Location_LLDC: Asia',
 'Location_LLDC: Europe',
 'Location_LLDC: Latin America',
 'Location_Land-locked Countries',
 'Location_Land-locked Countries (Others)',
 'Location_Land-locked Developing Countries (LLDC)',
 "Location_Lao People's Democratic Republic",
 'Location_Latin America and the Caribbean',
 'Location_Latin American Integration Association (ALADI)',
 'Location_Latin American and Caribbean Group (GRULAC)',
 'Location_Latvia',
 'Location_League of Arab States (LAS; informal name: Arab League)',
 'Location_Least developed countries',
 'Location_Least developed: Africa',
 'Location_Least developed: Asia',
 'Location_Least developed: Latin America and the Caribbean',
 'Location_Least developed: Oceania',
 'Location_Lebanon',
 'Location_Lesotho',
 'Location_Less developed regions',
 'Location_Less developed regions; excluding China',
 'Location_Less developed regions; excluding least developed countries',
 'Location_Less developed: Africa',
 'Location_Less developed: Asia',
 'Location_Less developed: Latin America and the Caribbean',
 'Location_Less developed: Oceania',
 'Location_Liberia',
 'Location_Libya',
 'Location_Lithuania',
 'Location_Low-income countries',
 'Location_Lower-middle-income countries',
 'Location_Luxembourg',
 'Location_Madagascar',
 'Location_Malawi',
 'Location_Malaysia',
 'Location_Maldives',
 'Location_Mali',
 'Location_Malta',
 'Location_Martinique',
 'Location_Mauritania',
 'Location_Mauritius',
 'Location_Mayotte',
 'Location_Melanesia',
 'Location_Mexico',
 'Location_Micronesia',
 'Location_Micronesia (Fed. States of)',
 'Location_Middle Africa',
 'Location_Middle-income countries',
 'Location_Mongolia',
 'Location_Montenegro',
 'Location_More developed regions',
 'Location_More developed: Asia',
 'Location_More developed: Europe',
 'Location_More developed: Northern America',
 'Location_More developed: Oceania',
 'Location_Morocco',
 'Location_Mozambique',
 'Location_Myanmar',
 'Location_Namibia',
 'Location_Nepal',
 'Location_Netherlands',
 'Location_Netherlands (and dependencies)',
 'Location_New Caledonia',
 'Location_New EU member states (joined since 2004)',
 'Location_New Zealand',
 'Location_New Zealand (and dependencies)',
 'Location_Nicaragua',
 'Location_Niger',
 'Location_Nigeria',
 'Location_No income group available',
 'Location_Non-Self-Governing Territories',
 'Location_North American Free Trade Agreement (NAFTA)',
 'Location_North Atlantic Treaty Organization (NATO)',
 'Location_North Macedonia',
 'Location_Northern Africa',
 'Location_Northern Africa and Western Asia',
 'Location_Northern Europe',
 'Location_Norway',
 'Location_Oceania (excluding Australia and New Zealand)',
 'Location_Oman',
 'Location_Organisation for Economic Co-operation and Development (OECD)',
 'Location_Organization for Security and Co-operation in Europe (OSCE)',
 'Location_Organization of American States (OAS)',
 'Location_Organization of Petroleum Exporting countries (OPEC)',
 'Location_Organization of the Islamic Conference (OIC)',
 'Location_Pakistan',
 'Location_Panama',
 'Location_Papua New Guinea',
 'Location_Paraguay',
 'Location_Peru',
 'Location_Philippines',
 'Location_Poland',
 'Location_Polynesia',
 'Location_Portugal',
 'Location_Puerto Rico',
 'Location_Qatar',
 'Location_Republic of Korea',
 'Location_Republic of Moldova',
 'Location_Romania',
 'Location_Russian Federation',
 'Location_Rwanda',
 'Location_Réunion',
 'Location_SIDS Atlantic; and Indian Ocean; Mediterranean and South China Sea (AIMS)',
 'Location_SIDS Caribbean',
 'Location_SIDS Pacific',
 'Location_Saint Lucia',
 'Location_Saint Vincent and the Grenadines',
 'Location_Samoa',
 'Location_Sao Tome and Principe',
 'Location_Saudi Arabia',
 'Location_Senegal',
 'Location_Serbia',
 'Location_Seychelles',
 'Location_Shanghai Cooperation Organization (SCO)',
 'Location_Sierra Leone',
 'Location_Singapore',
 'Location_Slovakia',
 'Location_Slovenia',
 'Location_Small Island Developing States (SIDS)',
 'Location_Solomon Islands',
 'Location_Somalia',
 'Location_South Africa',
 'Location_South Asian Association for Regional Cooperation (SAARC)',
 'Location_South Sudan',
 'Location_South-Eastern Asia',
 'Location_Southern Africa',
 'Location_Southern African Development Community (SADC)',
 'Location_Southern Asia',
 'Location_Southern Common Market (MERCOSUR)',
 'Location_Southern Europe',
 'Location_Spain',
 'Location_Sri Lanka',
 'Location_State of Palestine',
 'Location_Sub-Saharan Africa',
 'Location_Sudan',
 'Location_Suriname',
 'Location_Sweden',
 'Location_Switzerland',
 'Location_Syrian Arab Republic',
 'Location_Tajikistan',
 'Location_Thailand',
 'Location_Timor-Leste',
 'Location_Togo',
 'Location_Tonga',
 'Location_Trinidad and Tobago',
 'Location_Tunisia',
 'Location_Turkey',
 'Location_Turkmenistan',
 'Location_UN-ECE: member countries',
 'Location_UNFPA Regions',
 'Location_UNFPA: Arab States (AS)',
 'Location_UNFPA: Asia and the Pacific (AP)',
 'Location_UNFPA: East and Southern Africa (ESA)',
 'Location_UNFPA: Eastern Europe and Central Asia (EECA)',
 'Location_UNFPA: Latin America and the Caribbean (LAC)',
 'Location_UNFPA: West and Central Africa (WCA)',
 'Location_UNICEF PROGRAMME REGIONS',
 'Location_UNICEF Programme Regions: East Asia and Pacific (EAPRO)',
 'Location_UNICEF Programme Regions: Eastern Caribbean',
 'Location_UNICEF Programme Regions: Eastern and Southern Africa (ESARO)',
 'Location_UNICEF Programme Regions: Europe and Central Asia (CEECIS)',
 'Location_UNICEF Programme Regions: Latin America',
 'Location_UNICEF Programme Regions: Latin America and Caribbean (LACRO)',
 'Location_UNICEF Programme Regions: Middle East and North Africa (MENARO)',
 'Location_UNICEF Programme Regions: South Asia (ROSA)',
 'Location_UNICEF Programme Regions: West and Central Africa (WCARO)',
 'Location_UNICEF REGIONS',
 'Location_UNICEF Regions: East Asia and Pacific',
 'Location_UNICEF Regions: Eastern Europe and Central Asia',
 'Location_UNICEF Regions: Eastern and Southern Africa',
 'Location_UNICEF Regions: Europe and Central Asia',
 'Location_UNICEF Regions: Latin America and Caribbean',
 'Location_UNICEF Regions: Middle East and North Africa',
 'Location_UNICEF Regions: North America',
 'Location_UNICEF Regions: South Asia',
 'Location_UNICEF Regions: Sub-Saharan Africa',
 'Location_UNICEF Regions: West and Central Africa',
 'Location_UNICEF Regions: Western Europe',
 'Location_UNITED NATIONS Regional Groups of Member States',
 'Location_Uganda',
 'Location_Ukraine',
 'Location_United Arab Emirates',
 'Location_United Kingdom',
 'Location_United Kingdom (and dependencies)',
 'Location_United Nations Economic Commission for Africa (UN-ECA)',
 'Location_United Nations Economic Commission for Latin America and the Caribbean (UN-ECLAC)',
 'Location_United Nations Economic and Social Commission for Asia and the Pacific (UN-ESCAP) Regions',
 'Location_United Nations Member States',
 'Location_United Republic of Tanzania',
 'Location_United States Virgin Islands',
 'Location_United States of America',
 'Location_United States of America (and dependencies)',
 'Location_Upper-middle-income countries',
 'Location_Uruguay',
 'Location_Uzbekistan',
 'Location_Vanuatu',
 'Location_Venezuela (Bolivarian Republic of)',
 'Location_Viet Nam',
 'Location_WB region: East Asia and Pacific (excluding high income)',
 'Location_WB region: Europe and Central Asia (excluding high income)',
 'Location_WB region: Latin America and Caribbean (excluding high income)',
 'Location_WB region: Middle East and North Africa (excluding high income)',
 'Location_WB region: South Asia (excluding high income)',
 'Location_WB region: Sub-Saharan Africa (excluding high income)',
 'Location_WHO Regions',
 'Location_WHO: African region (AFRO)',
 'Location_WHO: Americas (AMRO)',
 'Location_WHO: Eastern Mediterranean Region (EMRO)',
 'Location_WHO: European Region (EURO)',
 'Location_WHO: South-East Asia region (SEARO)',
 'Location_WHO: Western Pacific region (WPRO)',
 'Location_West African Economic and Monetary Union (UEMOA)',
 'Location_Western Africa',
 'Location_Western Asia',
 'Location_Western Europe',
 'Location_Western European and Others Group (WEOG)',
 'Location_Western Sahara',
 'Location_World',
 'Location_World Bank Regional Groups (developing only)',
 'Location_Yemen',
 'Location_Zambia',
 'Location_Zimbabwe'])
df.head()

# %%
df.dtypes

# %%
df.head(500)

# %%
new_df = ['Europe','Asia','Africa','Northern America','Central America','South America']

# %%
new_df = df[new_df]

# %%
#pip install pandas-profiling

# %%
import pandas_profiling
#pandas_profiling.ProfileReport(df)
